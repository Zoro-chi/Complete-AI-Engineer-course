# %% [markdown]
# ## First Graph: Defining a State and a Node

# %% [markdown]
# ### Set the OpenAI API Key as an Environment Variable

# %%
# %load_ext dotenv
# %dotenv
# %load_ext mypy_ipython

# %% [markdown]
# ### Import Relevant Classes and Functions

# %%
from langgraph.graph import START, END, StateGraph
from typing_extensions import TypedDict
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage, BaseMessage
from langchain_core.runnables import Runnable
from collections.abc import Sequence

# %% [markdown]
# ### Define the State

# %%
class State(TypedDict):
    messages: Sequence[BaseMessage]

# %%
state = State(messages = [HumanMessage("Could you tell me a verse by Ye?")])

# %%
state["messages"][0].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Could you tell me a verse by Ye?

# %% [markdown]
# ### Define the Nodes

# %%
chat = ChatOpenAI(model = "gpt-4o-mini", 
                  seed = 365, 
                  temperature = 0, 
                  max_completion_tokens = 100)

# %%
response = chat.invoke(state["messages"])

# %%
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Sure! One of Kanye West's well-known verses is from his song "Runaway." In it, he reflects on his flaws and relationships. If you’d like, I can summarize the themes or discuss the song further!

# %%
def chatbot(state: State) -> State:
    
    print(f"\n-------> ENTERING chatbot:")
    
    response = chat.invoke(state["messages"])
    response.pretty_print()
    
    return State(messages = [response])

# %%
chatbot(state)
# Out:
# -------> ENTERING chatbot:
# ================================== Ai Message ==================================
#
# Sure! One of Kanye West's well-known verses is from his song "Runaway." In it, he reflects on his flaws and relationships. If you’d like, I can summarize the themes or discuss the song further!
# {'messages': [AIMessage(content='Sure! One of Kanye West\'s well-known verses is from his song "Runaway." In it, he reflects on his flaws and relationships. If you’d like, I can summarize the themes or discuss the song further!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 16, 'total_tokens': 61, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_1590f93f9d', 'id': 'chatcmpl-D58w1A2yBiL4bEfSZbT93ta2inraq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--8aeeb3bb-a88f-4b85-bc20-adca34730720-0', usage_metadata={'input_tokens': 16, 'output_tokens': 45, 'total_tokens': 61, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
